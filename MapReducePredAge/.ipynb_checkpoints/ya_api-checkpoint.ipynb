# %%
#!/usr/bin/python

import sys
import re
import urlparse
import json
import xml.etree.cElementTree as ET
import urllib2


# %pylab inline
import numpy
import matplotlib.pyplot as plot
import pandas as pd

from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.grid_search import GridSearchCV
from sklearn.svm import LinearSVC

# %%
def url2domain(url):
    
    try:
        a = urlparse.urlparse(urllib.unquote(url.strip()))
        
        if (a.scheme in ['http','https']):
            b = re.search("(?:www\.)?(.*)",a.netloc).group(1)
            if b is not None:
                stripUrl = str(b).strip()
                return stripUrl
                if stripUrl in url2MetaUrl:
                    if url2MetaUrl[stripUrl]:
                        return url2MetaUrl[str(b).strip()]
                    else:
                        return ''
                else:
                    return stripUrl
            else:
                return ''
        else:
            return ''
    except:
        return ''

# %%
curUDict = {}

for l in open('gender_age_dataset_h.txt')[:10]:
    parts = l.strip().split('\t')
    if len(parts) < 4:
        continue
    try:
        localDict = {}
        j = json.loads(parts[3])
        for u in j['visits']:
            curUrl = url2domain(u['url'])
            if curUrl and not curUrl in localDict:
                localDict[curUrl] = 1
                if curUrl in curUDict:
                    curUDict[curUrl] = curUDict[curUrl] + 1
                else:
                    curUDict[curUrl] = 1
    except:
        continue

# %%
i = 0
filterDict = {'http:': True, 'https:': True}
curNewDict = {}
for u in sorted(curUDict):
    if u in filterDict:
        continue
    if curUDict[u] > 17:
        curNewDict[u] = i
        i = i + 1
    
len(curNewDict)
# Out:
# 4412

# %%
'''topicDict = {}
i = 0
for u in curNewDict:
    if u in topicDict:
        continue
    tree = ET.ElementTree(file=urllib2.urlopen('http://bar-navig.yandex.ru/u?show=31&url=http://' + u ))
    t = tree.find('topics')
    if t:
        t = t.find('topic').get('title')
        if t:
            topic = t.replace(u'Тема: ', '')
            topicDict[u] = topic
            print u + ' ' + topic + ' ' + str(i)
    else:
        print u + ' :( Unknown'
    i += 1'''

topicDict = json.load(open('url_topic.json'))

# %%
urls = [x for x in sorted(curNewDict)]

curLen = len(urls)
uniqueTopic = {}

for u in topicDict:
    uniqueTopic[topicDict[u]] = topicDict[u]

for u in uniqueTopic:
    urls.append(u)
    uniqueTopic[u] = curLen
    curLen += 1

checkFields = ['gender', 'age1', 'age2', 'age3', 'age4', 'age5']
len(urls)
# Out:
# 4773

# %%
knownSet = []
checkSet = []
unknownSet = []
uidSet = []

urlLen = len(urls)

age2idx = {
    '18-24': 1,
    '25-34': 2,
    '35-44': 3,
    '45-54': 4,
    '>=55': 5,
}

excludeTopics = {u'Реклама': True, u'Поисковые системы': True, u'Баннерные сети': True}

for l in open('lab06/gender_age_dataset.txt'):
    userSet = [0] * urlLen
    parts = l.strip().split('\t')
    added = False
    if len(parts) < 4:
        print('skip ' + l.strip())
        continue
    try:
        j = json.loads(parts[3])
        for u in j['visits']:
            curUrl = url2domain(u['url'])
            if curUrl in curNewDict:
                if curUrl in topicDict:
                    if not topicDict[curUrl] in excludeTopics:
                        added = True
                        if not userSet[curNewDict[curUrl]]:
                            userSet[uniqueTopic[topicDict[curUrl]]] += 1
                        userSet[curNewDict[curUrl]] = 1
                else:
                    added = True
                    userSet[curNewDict[curUrl]] = 1
    except Exception as e:
        print('except!! ' + str(e))
        continue
        
    if parts[0] == '-' or parts[1] == '-': 
        uidSet.append([parts[2], added])        
        unknownSet.append(userSet)         
    else:        
        if not added:
            continue   
        
        knownSet.append(userSet)
        
        curCheckSet = [0] * 6
        if parts[0] == 'F':            
            curCheckSet[0] = 0
        else:  
            curCheckSet[0] = 1
        curCheckSet[age2idx[parts[1]]] = 1
        checkSet.append(curCheckSet)

len(knownSet)
# Out:
# except!! No JSON object could be decoded
# 33746

# %%
emptyColumns = []
for j in range(len(urls)):
    ifKnown = False
    ifUnknown = False
    if True in any(i > 0 for i in [row[j] for row in knownSet]):
        continue
    else:
        ifKnown = True   
    if True in any(i > 0 for i in [row[j] for row in unknownSet]):
        continue
    else:
        ifUnknown = True
    if ifKnown and ifUnknown:
        emptyColumns.append(j)
        
len(emptyColumns)
# Out:
# 132

# %%
dfKnown = pd.DataFrame(knownSet, columns=urls) 
dfCheckSet = pd.DataFrame(checkSet, columns=checkFields)
dfUnknown = pd.DataFrame(unknownSet, columns=urls)

# %%
for i in emptyColumns:
    del dfKnown[urls[i]]
    del dfUnknown[urls[i]]

# %%
dfKnown.shape
# Out:
# (33746, 4641)

# %%
X_train, X_test, y_train, y_test = train_test_split(dfKnown, dfCheckSet, test_size=0.25, random_state=5, stratify=dfCheckSet)

testMode = True

# %%
X_test = dfUnknown

testMode = False

# %%
predictions = {}
for u in checkFields:
    model = LogisticRegression(C=0.0009765625, penalty='l2')
    model.fit(X_train, y_train[u])
    predictions[u] = model.predict_proba(X_test)
    classif = LinearSVC( C=0.0009765625, penalty='l2' )
    classif.fit(X_train, y_train[u])
    predictions[u + '_svc'] = classif.decision_function(X_test)
    
print len(predictions)
# Out:
# 12

# %%
prComposed = {}

for i in range(len(X_test)):
    tmpSet = {}
    for u in checkFields:
         tmpSet[u] = [predictions[u][i][1], predictions[u + '_svc'][i]]
    prComposed[i] = tmpSet
    
prComposed
# Out:
# {0: {'age1': [0.0017063637402185935, -1.6071383064627121],
#   'age2': [0.18639864749232157, -0.38049795867891328],
#   'age3': [0.22521579549758666, -0.78547754563682837],
#   'age4': [0.28787889283974211, -0.41323373232999344],
#   'age5': [0.1238087646331288, -0.44059434302182099],
#   'gender': [0.99679756070772696, 3.2932640505798432]},
#  1: {'age1': [0.057091500791756095, -0.7884875947888047],
#   'age2': [0.57931734785036892, 0.19813417261608318],
#   'age3': [0.20066878454084741, -0.72911222429611167],
#   'age4': [0.067521850631707833, -0.9508619941768055],
#   'age5': [0.021280709733726578, -0.8779470925942402],
#   'gender': [0.22952127654798807, -0.72981588370980433]},
#  2: {'age1': [0.15132025585046471, -0.73673560546947148],
#   'age2': [0.43800166978141153, -0.083975862012883526],
#   'age3': [0.26399264177171383, -0.46291954959647458],
#   'age4': [0.15655456837535303, -0.71561677232917809],
#   'age5': [0.067940500803852708, -0.96815031879103608],
#   'gender': [0.52844056337110212, 0.15855031119954735]},
#  3: {'age1': [0.13331384426002638, -0.70620046346003129],
#   'age5': [0.071827439912993091, -0.78819111033991651],
#   'gender': [0.30028941883872506, -0.54065218487073752]},
#  50: {'age1': [0.074826224142032147, -1.0407944132527787],
#   'age2': [0.31946593353253311, -0.60327703439917812],
#   'age3': [0.29964299221197815, -0.27050682765719625],
#   'age4': [0.19325526061613107, -0.47416285557255389],
#   'age5': [0.11319961258379423, -0.67721125150005168],
#   'gender': [0.64394995736422378, 0.41063783159412887]},
#  51: {'age1': [0.15771581825108408, -0.75693796136645497],
#   'age2': [0.42787808199608873, -0.13304204590175706],
#   'age3': [0.29717000153053685, -0.33294535081125387],
#   'age4': [0.13135458838759478, -0.79787988864111592],
#   'age5': [0.05833230313886624, -0.95776049302439858],
#   'gender': [0.44911295011038022, 0.035455376448578227]},
#  52: {'age1': [0.17664020967117475, -0.66888563985579041],
#   'age2': [0.48332511342113066, -0.088032948348933215],
#   'age3': [0.24823572684129094, -0.5218586551958202],
#   'age4': [0.12344406370892359, -0.77661352328245259],
#   'age5': [0.058219915557924724, -0.93631057323933498],
#   'gender': [0.62914074330005487, 0.35130064991155069]},
#  53: {'age1': [0.17201192120457645, -0.38545832041649486],
#   'age2': [0.48271294493096939, 0.053657779665733499],
#   'age3': [0.27346870470950363, -0.47199313275335314],
#   'age4': [0.072269046757590327, -1.2485035247179015],
#   'age5': [0.029160562935734904, -1.0336118346203997],
#   'gender': [0.16569585724765123, -1.6131534801660017]},
#  54: {'age1': [0.016417421151073541, -0.96684080312821341],
#   'age2': [0.44748597772457421, 0.6836818142658706],
#   'age3': [0.20818853035527235, -1.1406892305885137],
#   'age4': [0.073500499080195347, -1.3669255222339876],
#   'age5': [0.032682800877997166, -0.94740708531805384],
#   'gender': [0.91204676418470665, 0.93845680268682907]},
#  55: {'age1': [0.16877503818989009, -0.70799197732565722],
#   'age2': [0.39793812820530949, -0.29696161804545929],
#   'age3': [0.26778682446261481, -0.46042983118642472],
#   'age4': [0.13839238851356436, -0.74750540852275416],
#   'age5': [0.065002125992846868, -0.85262576126036183],
#   'gender': [0.39369719433247269, -0.10429797025645154]},
#  56: {'age1': [0.18838247799560259, -0.72040898957991961],
#   'age2': [0.49860710266040864, 0.1156737323562768],
#   'age3': [0.20574880274460533, -0.54639800433648389],
#   'age4': [0.11381422900017769, -0.89229479663535005],
#   'age5': [0.051184943054340716, -0.98405847813697722],
#   'gender': [0.31305041735504918, -0.4073522488038358]},
#  57: {'age1': [0.16687534906504597, -0.73303139576355347],
#   'age2': [0.44348630644583664, -0.15500947628323078],
#   'age3': [0.26461214809654421, -0.42878646290181943],
#   'age4': [0.14184841475150647, -0.74005813551168786],
#   'age5': [0.06994029310577729, -0.9082965778845884],
#   'gender': [0.48918925859778822, 0.012859590110123574]},
#  58: {'age1': [0.026270388327754527, -0.90091643202907545],
#   'age2': [0.19124057913085543, -0.74241844474230612],
#   'age3': [0.21411998901407042, -0.77754122261173908],
#   'age4': [0.26939312061633763, -0.45566393090220059],
#   'age5': [0.13126886222696391, -0.43202497420841524],
#   'gender': [0.3223705125569295, -0.46047524530020623]},
#   'age2': [0.36479598928724222, -0.26318057670482176],
#   'age3': [0.28641171547329375, -0.46904847246124309],
#   'age4': [0.20711821636180708, -0.57924298146122988],
#   'age5': [0.08123752204506203, -0.87342759879548304],
#   'gender': [0.57487834349549971, 0.14984877925715209]},
#  125: {'age1': [0.0041031282521378394, -1.2600950190718208],
#   'age2': [0.098801948471327533, -1.3342791268654692],
#   'age3': [0.29283347206599614, -0.56504560197821985],
#   'age4': [0.57439768229832222, 0.23147226340187144],
#   'age5': [0.22476851702604106, -0.42152044860156179],
#   'gender': [0.051841106564942022, -1.8874263350201672]},
#  126: {'age1': [0.0839506870538132, -0.79386795971981394],
#   'age2': [0.35656213095446876, -0.35685738874151623],
#   'age3': [0.25973838665722987, -0.58324543567980669],
#   'age4': [0.18492291731510749, -0.56615714848734433],
#   'age5': [0.10291668570981384, -0.66623328838807483],
#   'gender': [0.57917016946916455, 0.057466603475489271]},
#  127: {'age1': [0.048117580304341177, -1.1577380972504154],
#   'age2': [0.35925981635866078, -0.0016928494426054624],
#   'age3': [0.3398274310711093, -0.39452986734893619],
#   'age4': [0.23084324867652015, -0.60318323472699187],
#   'age5': [0.081428723845219333, -0.93332543009121305],
#   'gender': [0.73953547777149242, 0.76309553769674243]},
#  128: {'age1': [0.12518368256270809, -0.84708013783290781],
#   'age2': [0.46641115494945395, 0.078622613350256068],
#   'age3': [0.25821418289222259, -0.46640853827359391],
#   'age4': [0.14986442594778746, -0.76894656663958738],
#   'age5': [0.069241609283207273, -0.98034548211206363],
#   'gender': [0.4977599090900004, 0.022466611032668539]},
#  129: {'age1': [0.12140878667116001, -0.81395436372688046],
#   'age2': [0.37139190042947345, -0.37290978895186233],
#   'age3': [0.2772449399279806, -0.41784590939665639],
#   'age4': [0.17965754340427872, -0.51418520833198533],
#   'age5': [0.069320453886180147, -0.90614284508380682],
#   'gender': [0.47069047696844757, -0.063104206406435825]},
#  130: {'age1': [0.19161905253373721, -0.58129805680629365],
#   'age2': [0.47396344816769148, -0.050345447962257726],
#   'age3': [0.23648448900131677, -0.58477872690523525],
#   'age4': [0.12549986626112444, -0.79014785114594221],
#   'age5': [0.059623235673715268, -0.96166500636201491],
#   'gender': [0.45956318341614677, -0.18396194486510525]},
#  131: {'age1': [0.041032966907178885, -0.99940097674629724],
#   'age2': [0.32826165928049295, -0.3093793830882558],
#   'age3': [0.28331473597034379, -0.61587495117695046],
#   'age4': [0.22599214126071046, -0.4700110997885466],
#   'age5': [0.11940336543734083, -0.70512701088650842],
#   'gender': [0.6831668853151116, 0.15701968447688719]},
#  132: {'age1': [0.048877995807451474, -1.2089401644580886],
#   'age2': [0.31572768787399724, -0.50989859813234695],
#   'age3': [0.35701920139675253, -0.092764593339010937],
#   'age4': [0.12986345902615992, -0.86542498800035661],
#   'age5': [0.094827944551938659, -0.49203563711954135],
#   'gender': [0.61356343433143867, 0.26696919054704005]},
#  133: {'age1': [0.11705460127842854, -0.87439577390565049],
#   'age2': [0.38387511408541103, -0.29577726799057502],
#   'age3': [0.32431810308609221, -0.24981860959558236],
#   'age4': [0.15262386669954847, -0.68518950741079931],
#   'age5': [0.057723948618527192, -0.89575996876427144],
#   'gender': [0.47872628089220637, -0.048432301627512449]},
#  134: {'age1': [0.14093117808518107, -0.78031647378994007],
#   'age2': [0.39878398648885399, -0.20684208202936533],
#   'age3': [0.28109828743834875, -0.46789575541643902],
#   'age4': [0.17963872721740881, -0.54119218987483764],
#   'age5': [0.058144658672831098, -1.0316934720944184],
#   'gender': [0.33175893816800406, -0.50961120160004414]},
#  135: {'age1': [0.19972449972184578, -0.61677347863821519],
#   'age2': [0.47568650742620605, -0.059678545867983865],
#   'age3': [0.2411478840589838, -0.52206983844566368],
#   'age4': [0.10927221729406192, -0.82055414201157351],
#   'age5': [0.051926743873415671, -0.97079732365948423],
#   'gender': [0.60244417879129797, 0.18769963963350603]},
#  136: {'age1': [0.15249837391739604, -0.78956285103897539],
#   'age2': [0.42111630974271436, -0.2016855787415156],
#   'age3': [0.2696192427679705, -0.41745345486870883],
#   'age4': [0.15325946942924931, -0.69192919918026685],
#   'age5': [0.075789841327535842, -0.87259837092861758],
#   'gender': [0.51154805898922762, 0.06050410185387279]},
#  137: {'age1': [0.15148666491094628, -0.76485933047406773],
#   'age2': [0.42247558306563937, -0.19468666625042697],
#   'age3': [0.26984934273916039, -0.47465855726425882],
#   'age4': [0.16064321101611775, -0.61021773787674505],
#   'age5': [0.069940468735478489, -0.92910612665727355],
#   'gender': [0.49953239176720232, -0.0091798457546082984]},
#  138: {'age1': [0.18730973205631338, -0.58326946244616928],
#   'age2': [0.45950865514906303, -0.058219646146619168],
#   'age3': [0.26586625844456974, -0.51834926705228812],
#   'age4': [0.10756719824653904, -0.88171636190284941],
#   'age5': [0.052014848510796782, -0.94419580093042244],
#   'gender': [0.55589085196010879, 0.12100785345025769]},
#  139: {'age1': [0.067518666605860853, -0.50457915768272055],
#   'age2': [0.34821768034350681, -0.7001861619629941],
#   'age3': [0.25737274833822332, -0.27587940811558925],
#   'age4': [0.090517081276042285, -0.91527743016201746],
#   'age5': [0.02350171857891617, -0.8934128985467763],
#   'gender': [0.93121198733235189, 1.5231233389259233]},
#  140: {'age1': [0.13000890035331836, -0.80274090540769349],
#   'age2': [0.4318392788868089, -0.17921163675330842],
#   'age3': [0.27124122256569738, -0.39627444670371936],
#   'age4': [0.14651378195855591, -0.70697779425569762],
#   'age5': [0.065062222484624815, -0.90022792145949637],
#   'gender': [0.49534912851720625, -0.02990990776667533]},
#  141: {'age1': [0.10132022969208067, -0.86089862645386295],
#   'age2': [0.28917200376042512, -0.59364086568091101],
#   'age3': [0.32250001097428349, -0.27628897504752153],
#   'age4': [0.18810996362724286, -0.68876746995719851],
#   'age5': [0.078180679592348326, -0.61898346521476832],
#   'gender': [0.3316697331298244, -0.77772876514861022]},
#  142: {'age1': [0.1595401984298066, -0.80611101931560092],
#   'age2': [0.46183038784961361, 0.016817163276571886],
# ...
#   'age5': [0.070488040388318199, -0.90741312176167399],
#   'gender': [0.48844996426536896, -0.023344553306667924]},
#  953: {'age1': [0.068679170464161235, -1.080417826474297],
#   'age2': [0.38036541318829487, -0.10375985159714581],
#   'age3': [0.36626838105093085, -0.045276290982897316],
#   'age4': [0.14186101052850603, -0.79620903641128049],
#   'age5': [0.031922093745412293, -1.1946876753826834],
#   'gender': [0.64875164072293601, 0.52012055455112094]},
#  954: {'age1': [0.17578435697420583, -0.60923925591108119],
#   'age2': [0.45007137344666087, -0.09274704688476032],
#   'age3': [0.24409345202828839, -0.5809725903597881],
#   'age4': [0.14055598280147188, -0.77859929497553504],
#   'age5': [0.066918244062793786, -0.92125544087537559],
#   'gender': [0.48925609611795384, 0.15053414184686981]},
#  955: {'age1': [0.097914570666855938, -0.80787049872681949],
#   'age2': [0.44185097432035203, 0.062575200568724607],
#   'age3': [0.24776440863555302, -0.59507046781732309],
#   'age4': [0.15798047359946579, -0.78769719868826837],
#   'age5': [0.099937585079737115, -0.90696009961349777],
#   'gender': [0.62803133370830999, 0.3244875081543368]},
#  956: {'age1': [0.11915032213732064, -1.0029476319594657],
#   'age2': [0.47583542762662301, -0.17071117029131627],
#   'age3': [0.25717689450828168, -0.37491096794322165],
#   'age4': [0.12156107247642257, -0.77678066438220694],
#   'age5': [0.063007278568182237, -0.71926652634593657],
#   'gender': [0.89377828386447356, 1.5815006197731416]},
#  957: {'age1': [0.083532686112402485, -1.2461380165569742],
#   'age2': [0.69024028858118025, 0.81889982274877482],
#   'age3': [0.23883316810260044, -0.33424885615241307],
#   'age4': [0.047826973339376209, -1.2512230810651763],
#   'age5': [0.01257574789612783, -1.4164018288987776],
#   'gender': [0.98929166070896657, 4.0537489230918293]},
#  958: {'age1': [0.16476704014515334, -0.7441837835104903],
#   'age2': [0.45855902341746191, -0.060392801646580049],
#   'age3': [0.25281732048499, -0.51373586383577619],
#   'age4': [0.13881556497413233, -0.76104155011303387],
#   'age5': [0.070704647659905806, -0.88599509203950599],
#   'gender': [0.51497778398072502, 0.095724574288535563]},
#  959: {'age1': [0.16951727917600987, -0.69924589251510705],
#   'age2': [0.44729168275803527, -0.1109247251133854],
#   'age3': [0.25918346377711338, -0.49699830228744674],
#   'age4': [0.14300359106363844, -0.74173928363566077],
#   'age5': [0.070488040388318199, -0.90741312176167399],
#   'gender': [0.48844996426536896, -0.023344553306667924]},
#  960: {'age1': [0.10912626690451405, -0.80936674341321724],
#   'age2': [0.38019872948406397, -0.23253453969286519],
#   'age3': [0.28774589183551086, -0.45203324110359178],
#   'age4': [0.18586832498904113, -0.63994431094320525],
#   'age5': [0.081583231134992135, -0.83732054582699078],
#   'gender': [0.53962542294265592, 0.015062941052512484]},
#  961: {'age1': [0.1682520562346303, -0.64087387715020749],
#   'age2': [0.44871645681035116, -0.041260558643181497],
#   'age3': [0.25062941682120993, -0.5962379575093375],
#   'age4': [0.14268007505844565, -0.83575483324839905],
#   'age5': [0.070351971840332761, -0.85521543394446564],
#   'gender': [0.4252288149991616, -0.14023433166011964]},
#  962: {'age1': [0.17256323961608461, -0.6946163833013469],
#   'age2': [0.44920695178170378, -0.10880497600278397],
#   'age3': [0.25568470633303697, -0.50015868564067412],
#   'age4': [0.14577475700434639, -0.69671323476161029],
#   'age5': [0.066408558944622845, -0.98244776648768128],
#   'gender': [0.45502081749819767, -0.2049045353315023]},
#  963: {'age1': [0.16878191577054955, -0.70949503961202909],
#   'age2': [0.44780274555324578, -0.10266554798430544],
#   'age3': [0.25943968476327761, -0.49399727581247749],
#   'age4': [0.14199895236790588, -0.77186428631272719],
#   'age5': [0.070991791734752951, -0.87727590991232884],
#   'gender': [0.48686413957120783, -0.03601564660594337]},
#  964: {'age1': [0.16281813712467044, -0.68611226054027619],
#   'age2': [0.43976317232045214, -0.12034149914877389],
#   'age3': [0.25313677082202818, -0.53676416016079176],
#   'age4': [0.15270552551861216, -0.71068309541528973],
#   'age5': [0.07012140016796424, -0.90884595208797436],
#   'gender': [0.44851861888346956, -0.042789736017355959]},
#  965: {'age1': [0.16333814173800998, -0.7649604316830092],
#   'age2': [0.4553045836685824, -0.095374359857096233],
#   'age3': [0.25001440242503065, -0.54947720500798614],
#   'age4': [0.13039088914636007, -0.66061339029842037],
#   'age5': [0.058317442879896854, -0.91911591685301464],
#   'gender': [0.60020078409231981, 0.17526642767792208]},
#  966: {'age1': [0.16694771982567261, -0.72847006845911921],
#   'age2': [0.43940859726379183, -0.10283929729524668],
#   'age3': [0.26814215510875772, -0.47373528560869749],
#   'age4': [0.14123299452432492, -0.75471988651575472],
#   'age5': [0.067094914080937595, -0.90636420339292978],
#   'gender': [0.4427527267932917, -0.12171649303012105]},
#  967: {'age1': [0.0091207966551308979, -1.2336953277970428],
#   'age2': [0.29026289646390308, -0.38490996090305724],
#   'age3': [0.25087164295100767, -0.51294560534134304],
#   'age4': [0.24406125789754315, -0.20785524447289583],
#   'age5': [0.090100886680385794, -0.94603894089680995],
#   'gender': [0.96774159673259308, 1.3810444352074125]},
#  968: {'age1': [0.14115932879646823, -0.73163374314277518],
#   'age2': [0.42241603434159664, -0.14570677698784917],
#   'age3': [0.25701808224827721, -0.46237061110530803],
#   'age4': [0.15739752255089176, -0.70471086051796827],
#   'age5': [0.083599155442473677, -0.90287338001013751],
#   'gender': [0.52891381241023061, 0.10050541399603352]},
#  969: {'age1': [0.1687533301785106, -0.69143801652156478],
#   'age2': [0.44345693614453019, -0.12593338640412377],
#   'age3': [0.25827006334524616, -0.53818063494885604],
#   'age4': [0.1418916850514276, -0.747110172289706],
#   'age5': [0.071660207758456829, -0.84290706003551263],
#   'gender': [0.52059499354329108, 0.163913539701143]},
#  970: {'age1': [0.085224512937421351, -0.9405517818531961],
#   'age2': [0.47967632071788119, 0.14075476416444904],
#   'age3': [0.26255452697550469, -0.41875692599199288],
#   'age4': [0.13947479738617891, -0.86760510111769018],
#   'age5': [0.065446588560380256, -0.92989806803120711],
#   'gender': [0.39037848321910879, -0.4989506888801491]},
#  971: {'age1': [0.16317890716060698, -0.72267101960604629],
#   'age2': [0.52557380202307069, 0.039458045723272092],
#   'age3': [0.23577159287197857, -0.45429733344336271],
#   'age4': [0.099231255872636245, -0.89458368597110904],
#   'age5': [0.040536765193660257, -0.96732902839529789],
#   'gender': [0.54294113113835574, 0.026722146443151358]},
#  972: {'age1': [0.19114517802276773, -0.54062935537659029],
#   'age2': [0.43662932648546382, -0.2008699851722317],
#   'age3': [0.25346381511707172, -0.56806340815802314],
#   'age4': [0.12310502317033349, -0.76813567303394392],
#   'age5': [0.061841519529773535, -0.91902872755070231],
#   'gender': [0.53791282191495415, 0.15354499125854723]},
#  973: {'age1': [0.19411448339891699, -0.62314533016200002],
#   'age2': [0.47074774360125649, -0.0095135964030915454],
#   'age3': [0.23781277382645349, -0.5773947040208478],
#   'age4': [0.12174285957090251, -0.79799603078462422],
#   'age5': [0.059648780186894616, -0.95993948847270405],
#   'gender': [0.47838784655714034, -0.047228640218959048]},
#  974: {'age1': [0.15590843751570033, -0.73652188713178923],
#   'age2': [0.48397562258367427, 0.13538257509718749],
#   'age3': [0.25427862616412678, -0.5394929126835365],
#   'age4': [0.12422613871524764, -0.8816485287399124],
#   'age5': [0.068092924123581075, -0.98695875545823097],
#   'gender': [0.5159697414055382, -0.09001851492753804]},
#  975: {'age1': [0.15472716945058698, -0.75708634671333441],
#   'age2': [0.44822002131461103, -0.11714615451027928],
#   'age3': [0.25973498230290304, -0.49727966395071443],
#   'age4': [0.14955246980195586, -0.67945264881804568],
#   'age5': [0.060638475697091805, -0.92298796107904135],
#   'gender': [0.61378346827660357, 0.31398974659574086]},
#  976: {'age1': [0.11358548641682822, -0.759092759687787],
#   'age2': [0.40495174941988965, -0.1956789790925742],
#   'age3': [0.28915468430004027, -0.4184480369818287],
#   'age4': [0.16851120732761424, -0.69814566247124255],
#   'age5': [0.065942935923514759, -0.89282537416427676],
#   'gender': [0.51423449004290622, -0.033729487624922984]},
#  977: {'age1': [0.15585341759578575, -0.73391331616706079],
#   'age2': [0.45718793403220215, -0.087445776742657119],
#   'age3': [0.25311948449719329, -0.49218518622264568],
#   'age4': [0.14336065764255013, -0.7316514444352743],
#   'age5': [0.063346046954140728, -0.92477880076934016],
#   'gender': [0.49252835999833933, -0.011821998808779609]},
#  978: {'age1': [0.16959039827936825, -0.69178486773224079],
#   'age2': [0.45133465700491182, -0.042173321973648772],
#   'age3': [0.25466320499871231, -0.55392451767546913],
#   'age4': [0.13864022753168906, -0.82400649897304168],
#   'age5': [0.072817512031082526, -0.86581192016550557],
#   'gender': [0.49118666323508603, -0.012671232587983031]},
#  979: {'age1': [0.16813104071590154, -0.65032878018902773],
#   'age2': [0.50324570108430167, 0.058780491352160666],
#   'age3': [0.24253540360744966, -0.55468973240236807],
#   'age4': [0.11172285086127776, -0.87280185881554739],
#   'age5': [0.053489566824066449, -0.96688462856820101],
#   'gender': [0.60205598500443425, 0.17645649316851933]},
#  980: {'age1': [0.17423747270078246, -0.70268269919094595],
#   'age2': [0.51319395287739633, 0.15049945910020268],
#   'age3': [0.23647401846668217, -0.65836782183816678],
#   'age4': [0.1112563297477835, -0.85851417314300038],
#   'age5': [0.057436001488763773, -0.95750195667191706],
#   'gender': [0.61614500487760704, 0.43860688683183879]},
#  981: {'age1': [0.20312538132545421, -0.59414840377848321],
#   'age2': [0.49036653153568999, 0.017702867220242877],
#   'age3': [0.1852685082621601, -0.70147710118491291],
#   'age4': [0.11399975061476472, -0.78532953550611906],
#   'age5': [0.047616177041618704, -0.94299567767489145],
#   'gender': [0.39165561594088966, -0.32124757364675244]},
#  982: {'age1': [0.18689289064693518, -0.62880292415939054],
#   'age2': [0.47986104711367822, 0.0077690094539431404],
#   'age3': [0.23043940954611214, -0.59037651955060044],
#   'age4': [0.12047746317247031, -0.81391955075341582],
#   'age5': [0.058278038150015837, -0.95061703944088638],
#   'gender': [0.41844886291470579, -0.19590040906858933]},
#  983: {'age1': [0.1752251233985154, -0.66037937005343528],
#   'age2': [0.4186070323210907, -0.16686508103846226],
#   'age3': [0.26723025808597917, -0.45907991521960789],
#   'age4': [0.12701647890948628, -0.75188194058499624],
#   'age5': [0.059328102391100042, -0.92595453693195606],
#   'gender': [0.44031324489847867, -0.035504315221705045]},
#  984: {'age1': [0.15753649688475288, -0.68272219633989928],
#   'age2': [0.49320204491405906, 0.092261381180238508],
#   'age3': [0.23814143273136373, -0.61719244372500814],
#   'age4': [0.099358278745747999, -0.96577668249842841],
#   'age5': [0.056371855093542984, -0.84348611340987967],
#   'gender': [0.59725703534313601, 0.37525222707652378]},
#  985: {'age1': [0.084062697403029088, -0.92227239084712309],
#   'age2': [0.39050340789386712, -0.20151840869211823],
#   'age3': [0.30023117792572379, -0.40553446826388229],
#   'age4': [0.1986083030920312, -0.5829271931882829],
#   'age5': [0.069748369329974969, -0.88995471947714766],
#   'gender': [0.50921932310493079, -0.0023917429675370874]},
#  986: {'age1': [0.15327256241480439, -0.74767205643493584],
#   'age2': [0.4272861189368794, -0.17965203026884036],
#   'age3': [0.27337913671567393, -0.43208446637194287],
#   'age4': [0.1455908193529358, -0.75872245214521072],
#   'age5': [0.072029673632553484, -0.85619386510057471],
#   'gender': [0.45591246657838552, -0.18943988686165847]},
#  987: {'age1': [0.15595886945076987, -0.72501450670159739],
#   'age2': [0.4512074604242739, -0.094984661400343243],
#   'age3': [0.2482325332519735, -0.53611873473044991],
#   'age4': [0.13892967511754045, -0.74609438407354378],
#   'age5': [0.073014519511965498, -0.853707910969426],
#   'gender': [0.47555418043086572, -0.053978363094931009]},
#  988: {'age1': [0.16134370434866802, -0.71723087903328919],
#   'age2': [0.48936231752271492, 0.032540386670235802],
#   'age3': [0.24771772994750171, -0.5485605167208949],
#   'age4': [0.12722570241680653, -0.82520257854289636],
#   'age5': [0.055034494222200421, -0.89851700397137657],
#   'gender': [0.59551320808655372, 0.27570124927363604]},
#  989: {'age1': [0.076481325017188503, -0.90806289092818837],
#   'age2': [0.41240664869401861, -0.16741775198555156],
#   'age3': [0.30679139153760243, -0.31238290015948966],
#   'age4': [0.18010257474850747, -0.68995661402295849],
#   'age5': [0.063172279656322619, -0.94026665551848354],
#   'gender': [0.69654296377257396, 0.43922366496993975]},
#  990: {'age1': [0.17205222123080888, -0.64525882604529361],
#   'age2': [0.45640526627959893, -0.0190948065932426],
#   'age3': [0.25242372802448049, -0.58209288966595729],
#   'age4': [0.14097228460189126, -0.78493163822859402],
#   'age5': [0.069690556431846615, -0.93092473459346059],
#   'gender': [0.49397540122956901, 0.012453146505994939]},
#  991: {'age1': [0.15879291703740678, -0.74811077498636058],
#   'age2': [0.47805755199149846, 0.081775741181346881],
#   'age3': [0.26858243764028583, -0.45438107271124717],
#   'age4': [0.1234145771075449, -0.90713313875263624],
#   'age5': [0.061348700721865067, -0.97679316998355104],
#   'gender': [0.45413809221119478, -0.18073920451889108]},
#  992: {'age1': [0.17028250255204053, -0.60752448802831349],
#   'age2': [0.44249281636855892, -0.13638990564708736],
#   'age3': [0.26880765509957832, -0.47470710495117358],
#   'age4': [0.13660497423717119, -0.7696589827436241],
#   'age5': [0.062817595848996821, -1.0083250086298783],
#   'gender': [0.39311986533087412, -0.38109526945891875]},
#  993: {'age1': [0.17169706116738126, -0.65592440093020199],
#   'age2': [0.4441822119693154, -0.15534496210095999],
#   'age3': [0.25851083596337432, -0.50279037114182246],
#   'age4': [0.1432891441650454, -0.72997291886889071],
#   'age5': [0.0701752028768967, -0.91846048570893657],
#   'gender': [0.48702625045208037, -0.044697327648032609]},
#  994: {'age1': [0.11439620170653557, -0.76950412958904357],
#   'age2': [0.37677730088542372, -0.27096399501277507],
#   'age3': [0.19447440986248038, -0.71458605009000498],
#   'age4': [0.20168699824498476, -0.56976360004324211],
#   'age5': [0.096823576022011165, -0.64919077126922997],
#   'gender': [0.4077553812312128, -0.40844469602596661]},
#  995: {'age1': [0.18183658469134473, -0.67810820076603229],
#   'age2': [0.44927138989316162, -0.13702058714713963],
#   'age3': [0.26339220416062159, -0.41478147715883978],
#   'age4': [0.13054554155302389, -0.78787454883660268],
#   'age5': [0.065096847653813822, -0.96140972812783931],
#   'gender': [0.49513434804088546, -0.014007140982989077]},
#  996: {'age1': [0.16720423049639874, -0.68178048333507424],
#   'age2': [0.48020882834591033, -0.033163177620904594],
#   'age3': [0.2487189794698817, -0.54462082829900493],
#   'age4': [0.12664728009637893, -0.76197678387649237],
#   'age5': [0.055839281300911404, -0.95502084704070789],
#   'gender': [0.53553437051425867, 0.094618801373160227]},
#  997: {'age1': [0.18132380931693592, -0.41121850485598971],
#   'age2': [0.42642359535302415, -0.23112205549227721],
#   'age3': [0.2454544835309686, -0.58361049420691868],
#   'age4': [0.13679182074442481, -0.78782110392211979],
#   'age5': [0.063601289664090524, -0.97348183459062099],
#   'gender': [0.46146744329039868, -0.24699833150089823]},
#  998: {'age1': [0.15761753148461966, -0.73619428780034357],
#   'age2': [0.44175747088081802, -0.099803679038085291],
#   'age3': [0.27329303603374339, -0.49567433512531345],
#   'age4': [0.13776729482068739, -0.70648517962006996],
#   'age5': [0.061813146554836246, -0.92800454956273404],
#   'gender': [0.41968764257627061, -0.26378148885924868]},
#  999: {'age1': [0.16951727917600987, -0.69924589251510705],
#   'age2': [0.44729168275803527, -0.1109247251133854],
#   'age3': [0.25918346377711338, -0.49699830228744674],
#   'age4': [0.14300359106363844, -0.74173928363566077],
#   'age5': [0.070488040388318199, -0.90741312176167399],
#   'gender': [0.48844996426536896, -0.023344553306667924]},
#  ...}

# %%
prComputed = {}
total = 0

tmpDict = {}

ageAmp = 0.197

for i in range(len(X_test)):
    if not testMode and not uidSet[i][1]:
        continue
    tmpSet = {}
    curDict = prComposed[i]
    genderWeight = 0
    genderLP = 0
    if curDict['gender'][0] > 0.5:
        genderLP = curDict['gender'][0] - 0.5
        genderWeight = genderLP * curDict['gender'][1]
    else:        
        genderLP = 0.5 - curDict['gender'][0]
        genderWeight = genderLP * -1 * curDict['gender'][1]
    
    ageWeight = -100
    agePredicted = 0
    for j in ['age1', 'age2', 'age3', 'age4', 'age5']:
        curWeight = curDict[j][0] * (ageAmp + max(0.001-ageAmp, curDict[j][1]))
        if curWeight > ageWeight:
            ageWeight = curWeight       
    tmpDict[i] = genderWeight * ageWeight
    
tmpDict2 = {}
i = 0
for w in sorted(tmpDict, key=tmpDict.get, reverse=True):
    tmpDict2[w] = False if i > (9999 if testMode else 2499)  else True
    i += 1

    
for i in range(len(X_test)):
    tmpSet = {}
    curDict = prComposed[i]
    if not i in tmpDict2 or not tmpDict2[i]:
        prComputed[i] = False
        continue
    genderLP = 0
    if curDict['gender'][0] > 0.5:
        tmpSet['gender'] = 1
        genderLP = curDict['gender'][0] - 0.5
    else:
        tmpSet['gender'] = 0
        genderLP = 0.5 - curDict['gender'][0] 
    ageWeight = -100
    ageChoose = ''
    agePredicted = 0
    for j in ['age1', 'age2', 'age3', 'age4', 'age5']:
        tmpSet[j] = 0
        curWeight = curDict[j][0] * (ageAmp + max(0.001-ageAmp, curDict[j][1]))
        if curWeight > ageWeight:
            ageWeight = curWeight 
            ageChoose = j
    tmpSet[ageChoose] = 1
    prComputed[i] = tmpSet
    total += 1
    
total
# Out:
# 2500

# %%
correct = 0
for i in range(len(X_test)):
    curCorrect = True
    if not prComputed[i]:
        continue
    for u in checkFields:
        if not y_test[i:i+1][u].item() == prComputed[i][u]:
            curCorrect = False
    if curCorrect:
        correct += 1
        
print float(correct) / float(total)
print total
# Out:
# 0.2148
# 2500

# %%
ageC2name = {
    'age1': '18-24',
    'age2': '25-34',
    'age3': '35-44',
    'age4': '45-54',
    'age5': '>=55',
}

prepareFinal = []
for u in range(len(X_test)):
    uid = uidSet[u][0]
    if not prComputed[u]:
        prepareFinal.append([uid, '-', '-'])        
        continue
    if prComputed[u]['gender'] == 1:
        gender = 'M'
    else:
        gender = 'F'    
    if prComputed[u]['age1'] == 1:
        age = '18-24'
    elif prComputed[u]['age2'] == 1:
        age = '25-34'
    elif prComputed[u]['age3'] == 1:
        age = '35-44'
    elif prComputed[u]['age4'] == 1:
        age = '45-54'
    elif prComputed[u]['age5'] == 1:
        age = '>=55'
    
    prepareFinal.append([uid, gender, age])
        
len(prepareFinal)
# Out:
# 5000

# %%
df06s = pd.DataFrame(prepareFinal, columns=['uid', 'gender', 'age'])

# %%
df06s.sort('uid').to_csv( "lab05s_gender-age.csv", index=False, sep='\t' )
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/kernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
