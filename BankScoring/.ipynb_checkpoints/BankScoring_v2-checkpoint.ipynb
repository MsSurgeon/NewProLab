# %%
from __future__ import division, print_function
# отключим всякие предупреждения Anaconda
import warnings
warnings.filterwarnings('ignore')
from scipy.stats import randint as sp_randint
import numpy as np
import pandas as pd
from time import time
from sklearn import preprocessing
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix
# %pylab inline
import seaborn as sns
figsize(12, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !ls
# Out:
# BankScoring.ipynb     BankScoring_v2.ipynb  laba04_train.csv
# BankScoring_v1.ipynb  laba04_test.csv

# %%
train_df = pd.read_csv('laba04_train.csv')
test_df = pd.read_csv('laba04_test.csv')

# %% [raw]
# for col in train_df.columns:
#     train_df[col] = train_df[col].replace(['O01','M01','K01'], 1)
#
#
# for col in test_df.columns:
#     test_df[col] = test_df[col].replace(['O01','M01','K01'],1)

# %%
#train_df = pd.concat([train_df, pd.get_dummies(train_df['PACK'], prefix="PACK")],axis=1)
#test_df = pd.concat([test_df, pd.get_dummies(train_df['PACK'], prefix="PACK")],axis=1)

train_df.drop(['Unnamed: 0', 'PACK'], axis=1, inplace=True)
test_df.drop(['Unnamed: 0', 'PACK'], axis=1, inplace=True)

# %% [raw]
# AGE	Возраст клиента (в месяцах)
# AMOUNT_RUB_ATM_PRC	Доля суммы транзакций по МСС ко сумме всех транзакций за период (в руб.)
# AMOUNT_RUB_CLO_PRC
# AMOUNT_RUB_NAS_PRC
# AMOUNT_RUB_SUP_PRC
# APP_CAR	Признак наличия автомобиля
# APP_COMP_TYPE	Тип компании (основной работы клиента)
# APP_DRIVING_LICENSE	Признак наличия водительского удостоверения
# APP_EDUCATION	Образование клиента
# APP_EMP_TYPE	Тип работы (занятость)
# APP_KIND_OF_PROP_HABITATION	Вид собственности жилья
# APP_MARITAL_STATUS	Семейное положение
# APP_POSITION_TYPE	Тип должности
# APP_REGISTR_RGN_CODE	Код региона регистрации
# APP_TRAVEL_PASS	Признак "есть заграничный паспорт"
# AVG_PCT_DEBT_TO_DEAL_AMT	Отношение задолженности к сумме кредита (среднее по аннуитетам)
# AVG_PCT_MONTH_TO_PCLOSE	Доля оставшегося срока кредита (среднее по аннуитетам)
# CLNT_JOB_POSITION	Должность клиента
# CLNT_JOB_POSITION_TYPE	Тип позиции
# CLNT_SALARY_VALUE	Зарплата клиента
# CLNT_SETUP_TENOR	Срок жизни клиента в банке
# CLNT_TRUST_RELATION	Тип созаемщика
# CNT_ACCEPTS_MTP	Число  принятый предложений в каналах / группах кампаний
# CNT_ACCEPTS_TK
# CNT_TRAN_ATM_TENDENCY1M	Тренд по кол-ву транзакции в разрезе MCC (за 1 или 3 месяца)
# CNT_TRAN_ATM_TENDENCY3M
# CNT_TRAN_AUT_TENDENCY1M
# CNT_TRAN_AUT_TENDENCY3M
# CNT_TRAN_CLO_TENDENCY1M
# CNT_TRAN_CLO_TENDENCY3M
# CNT_TRAN_MED_TENDENCY1M
# CNT_TRAN_MED_TENDENCY3M
# CNT_TRAN_SUP_TENDENCY1M
# CNT_TRAN_SUP_TENDENCY3M
# CR_PROD_CNT_CC	Кол-во открытых продуктов за отчетный период (по категориям продуктов)
# CR_PROD_CNT_CCFP
# CR_PROD_CNT_IL
# CR_PROD_CNT_PIL
# CR_PROD_CNT_TOVR
# CR_PROD_CNT_VCU
# DEAL_GRACE_DAYS_ACC_AVG	Показатели по грейсу за отчетный период
# DEAL_GRACE_DAYS_ACC_MAX
# DEAL_GRACE_DAYS_ACC_S1X1
# DEAL_YQZ_IR_MAX	Максимальная / минимальная процентная ставка по револьверам / аннуитетам за отчетный период
# DEAL_YQZ_IR_MIN
# DEAL_YWZ_IR_MAX
# DEAL_YWZ_IR_MIN
# LDEAL_ACT_DAYS_ACC_PCT_AVG	Показатели по времени активности за отчетный период (по кредитным договорам)
# LDEAL_ACT_DAYS_PCT_AAVG
# LDEAL_ACT_DAYS_PCT_CURR
# LDEAL_ACT_DAYS_PCT_TR
# LDEAL_ACT_DAYS_PCT_TR3
# LDEAL_ACT_DAYS_PCT_TR4
# LDEAL_AMT_MONTH	Прочие продуктовые параметры за отчетный период (кредитным договорам)
# LDEAL_DELINQ_PER_MAXYQZ
# LDEAL_DELINQ_PER_MAXYWZ
# LDEAL_GRACE_DAYS_PCT_MED
# LDEAL_TENOR_MAX
# LDEAL_TENOR_MIN
# LDEAL_USED_AMT_AVG_YQZ
# LDEAL_USED_AMT_AVG_YWZ
# LDEAL_YQZ_CHRG
# LDEAL_YQZ_COM
# LDEAL_YQZ_PC
# MAX_PCLOSE_DATE	Кол-во месяцев до даты планового закрытия (макс. по аннуитетам)
# MED_DEBT_PRC_YQZ	Медиана доли задолженности по аннуитетам / револьверам
# MED_DEBT_PRC_YWZ
# PACK	Пакет услуг
# PRC_ACCEPTS_A_AMOBILE	% отклика в каналах / продуктовых группах
# PRC_ACCEPTS_A_ATM
# PRC_ACCEPTS_A_EMAIL_LINK
# PRC_ACCEPTS_A_MTP
# PRC_ACCEPTS_A_POS
# PRC_ACCEPTS_A_TK
# PRC_ACCEPTS_MTP
# PRC_ACCEPTS_TK
# REST_AVG_CUR	Средние остатки по текущим счетам
# REST_AVG_PAYM	Средние остатки по зарплатным счетам
# REST_DYNAMIC_CC_1M	Тренд среднемесяцных остатков по продуктам за отчетный период ( за 1 или 3 месяца)
# REST_DYNAMIC_CC_3M
# REST_DYNAMIC_CUR_1M
# REST_DYNAMIC_CUR_3M
# REST_DYNAMIC_FDEP_1M
# REST_DYNAMIC_FDEP_3M
# REST_DYNAMIC_IL_1M
# REST_DYNAMIC_IL_3M
# REST_DYNAMIC_PAYM_1M
# REST_DYNAMIC_PAYM_3M
# REST_DYNAMIC_SAVE_3M
# SUM_TRAN_ATM_TENDENCY1M	Тренд по сумме транзакций по MCC за отчетный период (1 или 3 месяца)
# SUM_TRAN_ATM_TENDENCY3M
# SUM_TRAN_AUT_TENDENCY1M
# SUM_TRAN_AUT_TENDENCY3M
# SUM_TRAN_CLO_TENDENCY1M
# SUM_TRAN_CLO_TENDENCY3M
# SUM_TRAN_MED_TENDENCY1M
# SUM_TRAN_MED_TENDENCY3M
# SUM_TRAN_SUP_TENDENCY1M
# SUM_TRAN_SUP_TENDENCY3M
# TRANS_AMOUNT_TENDENCY3M	отношение суммы транзакций за три месяца к 6 месяцем
# TRANS_CNT_TENDENCY3M	отношение числа транзакций за три месяца к 6 месяцем
# TRANS_COUNT_ATM_PRC	Отношение транзакций по MCC ко всем транзакциям за отчетный период
# TRANS_COUNT_NAS_PRC
# TRANS_COUNT_SUP_PRC
# TURNOVER_CC	Средние обороты по кредитным картам
# TURNOVER_DYNAMIC_CC_1M	Тренд по среднемесячным оборотам за отчетный период (1 или 3 месяца)
# TURNOVER_DYNAMIC_CC_3M
# TURNOVER_DYNAMIC_CUR_1M
# TURNOVER_DYNAMIC_CUR_3M
# TURNOVER_DYNAMIC_IL_1M
# TURNOVER_DYNAMIC_IL_3M
# TURNOVER_DYNAMIC_PAYM_1M
# TURNOVER_DYNAMIC_PAYM_3M
# TURNOVER_PAYM	Средние обороты по зарплатным счетам
# TARGET	Фактический индикатор оттока

# %%
test_df.describe(include='all').T
# Out:
#                              count unique         top  freq         mean  \
# ID                           44399    NaN         NaN   NaN       369576
# CR_PROD_CNT_IL               44399    NaN         NaN   NaN     0.102029
# AMOUNT_RUB_CLO_PRC           39605    NaN         NaN   NaN    0.0440032
# PRC_ACCEPTS_A_EMAIL_LINK     19378    NaN         NaN   NaN            0
# APP_REGISTR_RGN_CODE          7525    NaN         NaN   NaN      51.2587
# PRC_ACCEPTS_A_POS            19378    NaN         NaN   NaN            0
# PRC_ACCEPTS_A_TK             19378    NaN         NaN   NaN            0
# TURNOVER_DYNAMIC_IL_1M       44399    NaN         NaN   NaN   0.00125581
# CNT_TRAN_AUT_TENDENCY1M       9667    NaN         NaN   NaN     0.412448
# SUM_TRAN_AUT_TENDENCY1M       9667    NaN         NaN   NaN     0.408287
# AMOUNT_RUB_SUP_PRC           39605    NaN         NaN   NaN     0.085391
# PRC_ACCEPTS_A_AMOBILE        19378    NaN         NaN   NaN            0
# ...

# %%
train_df.shape, test_df.shape
# Out:
# ((399589, 115), (44399, 114))

# %%
nan = []
for col in train_df.columns:
    if pd.isnull(train_df[col]).sum()/len(train_df[col]) > 0:
        nan.append([col, pd.isnull(train_df[col]).sum()/len(train_df[col])])
#print (pd.DataFrame(nan).to_string())
pd.DataFrame(nan).plot.hist(bins=50, figsize = [15,3])

# %%
nan = []
for col in train_df.columns:
    if pd.isnull(train_df[col]).sum()/len(train_df[col]) < 0.60 and pd.isnull(train_df[col]).sum()/len(train_df[col]) > 0 or\
            pd.isnull(test_df[col]).sum()/len(test_df[col]) < 0.60 and pd.isnull(test_df[col]).sum()/len(test_df[col]):
        nan.append([col, pd.isnull(train_df[col]).sum()/len(train_df[col]), train_df[col].dtype])
#print (pd.DataFrame(nan).to_string())
pd.DataFrame(nan).plot.hist(bins=50, figsize = [15,3])

# %%
for n in pd.DataFrame(nan).iloc[:,0]:
    if(train_df[n].dtype == np.float64 or train_df[n].dtype == np.int64):
        train_df[n] = train_df[n].fillna(train_df[n].median())
        test_df[n] = test_df[n].fillna(test_df[n].median())

# %%
nan = []
for col in train_df.columns:
    if pd.isnull(train_df[col]).sum()/len(train_df[col]) >= 0 or pd.isnull(test_df[col]).sum()/len(test_df[col]) >= 0:
        nan.append([col, pd.isnull(train_df[col]).sum()/len(train_df[col]), train_df[col].dtype])
#print (pd.DataFrame(nan).to_string())
pd.DataFrame(nan).plot.hist(bins=50, figsize = [15,3])

# %%
for n in pd.DataFrame(nan).iloc[:,0]:
    #if train_df[n].dtype == np.object:
        train_df.drop([n], axis=1, inplace=True)
        test_df.drop([n], axis=1, inplace=True)
    #else:   
     #   train_df[n] = train_df[n].fillna(train_df[n].median())
      #  test_df[n] = test_df[n].fillna(test_df[n].median())

# %% [raw]
# nan = []
# for col in train_df.columns:
#     if pd.isnull(train_df[col]).sum()/len(train_df[col]) > 0:
#         nan.append([col, pd.isnull(train_df[col]).sum()/len(train_df[col]), train_df[col].dtype])
# print (pd.DataFrame(nan).to_string())
# pd.DataFrame(nan).plot.hist(bins=50, figsize = [15,3])

# %%
y = train_df['TARGET']
train_df.drop(['TARGET'], axis=1, inplace=True)

# %% [raw]
# # train_df = pd.concat([train_df, pd.get_dummies(train_df['CLNT_TRUST_RELATION'], prefix="CLNT_TRUST_RELATION"),
#                       pd.get_dummies(train_df['APP_MARITAL_STATUS'], prefix="APP_MARITAL_STATUS"),
#                       pd.get_dummies(train_df['APP_KIND_OF_PROP_HABITATION'], prefix="APP_KIND_OF_PROP_HABITATION"),
#                       pd.get_dummies(train_df['CLNT_JOB_POSITION_TYPE'], prefix="CLNT_JOB_POSITION_TYPE"),
#                       pd.get_dummies(train_df['APP_DRIVING_LICENSE'], prefix="APP_DRIVING_LICENSE"),
#                       pd.get_dummies(train_df['APP_EDUCATION'], prefix="APP_EDUCATION"),
#                       pd.get_dummies(train_df['APP_TRAVEL_PASS'], prefix="APP_TRAVEL_PASS"),
#                       pd.get_dummies(train_df['APP_CAR'], prefix="APP_CAR"),
#                       pd.get_dummies(train_df['APP_POSITION_TYPE'], prefix="APP_POSITION_TYPE"),
#                       pd.get_dummies(train_df['APP_EMP_TYPE'], prefix="APP_EMP_TYPE"),
#                       pd.get_dummies(train_df['APP_COMP_TYPE'], prefix="APP_COMP_TYPE")],
#                      axis=1)
# test_df = pd.concat([test_df, pd.get_dummies(test_df['CLNT_TRUST_RELATION'], prefix="CLNT_TRUST_RELATION"),
#                       pd.get_dummies(test_df['APP_MARITAL_STATUS'], prefix="APP_MARITAL_STATUS"),
#                       pd.get_dummies(test_df['APP_KIND_OF_PROP_HABITATION'], prefix="APP_KIND_OF_PROP_HABITATION"),
#                       pd.get_dummies(test_df['CLNT_JOB_POSITION_TYPE'], prefix="CLNT_JOB_POSITION_TYPE"),
#                       pd.get_dummies(test_df['APP_DRIVING_LICENSE'], prefix="APP_DRIVING_LICENSE"),
#                       pd.get_dummies(test_df['APP_EDUCATION'], prefix="APP_EDUCATION"),
#                       pd.get_dummies(test_df['APP_TRAVEL_PASS'], prefix="APP_TRAVEL_PASS"),
#                       pd.get_dummies(test_df['APP_CAR'], prefix="APP_CAR"),
#                       pd.get_dummies(test_df['APP_POSITION_TYPE'], prefix="APP_POSITION_TYPE"),
#                       pd.get_dummies(test_df['APP_EMP_TYPE'], prefix="APP_EMP_TYPE"),
#                       pd.get_dummies(test_df['APP_COMP_TYPE'], prefix="APP_COMP_TYPE")],
#                      axis=1)

# %% [raw]
# train_df.drop(['CLNT_TRUST_RELATION','APP_MARITAL_STATUS','APP_KIND_OF_PROP_HABITATION', \
#               'CLNT_JOB_POSITION_TYPE','APP_DRIVING_LICENSE','APP_EDUCATION','APP_TRAVEL_PASS',\
#               'APP_CAR','APP_POSITION_TYPE','APP_EMP_TYPE','APP_COMP_TYPE'], axis=1, inplace=True)
# test_df.drop(['CLNT_TRUST_RELATION','APP_MARITAL_STATUS','APP_KIND_OF_PROP_HABITATION', \
#               'CLNT_JOB_POSITION_TYPE','APP_DRIVING_LICENSE','APP_EDUCATION','APP_TRAVEL_PASS',\
#               'APP_CAR','APP_POSITION_TYPE','APP_EMP_TYPE','APP_COMP_TYPE'], axis=1, inplace=True)

# %%
for e in list(set(train_df.columns)-set(test_df.columns)):
    print (e)

# %%
train_df.drop(list(set(train_df.columns)-set(test_df.columns)), axis=1, inplace=True)

# %% [raw]
# tree = RandomForestClassifier(max_depth=2, min_samples_leaf=2) # Ваш код здесь
# tree.fit(train_df,y)
# feaches = pd.DataFrame(tree.feature_importances_, columns=['Importance'], index=train_df.columns).sort_values(by='Importance', ascending=False)
# feaches.head()

# %%
# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

#tree_params = {'max_depth': [2, 3], 'min_samples_leaf': [2, 3]}
#cf = RandomizedSearchCV(,tree_params, n_jobs=-1,n_iter=10, scoring="f1",cv=5)
tree_params= {"max_depth": sp_randint(2, 10),
              "max_features": sp_randint(1, len(train_df.columns)),
              "min_samples_split": sp_randint(1, 10),
              "min_samples_leaf": sp_randint(1, 10),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

clf = RandomForestClassifier(n_estimators = 10,random_state=555, n_jobs=-1)

# run randomized search
n_iter_search = 20
random_search = RandomizedSearchCV(clf, param_distributions=tree_params, n_iter=n_iter_search, n_jobs=-1,\
                                                                                       random_search=True, cv=5)

start = time()
random_search.fit(train_df,y)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))

report(random_search.cv_results_)
# Out:
# RandomizedSearchCV took 191.63 seconds for 20 candidates parameter settings.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-c59482fa9d96> in <module>()
#      31       " parameter settings." % ((time() - start), n_iter_search))
#      32
# ---> 33 report(random_search.cv_results_)
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'cv_results_'

# %%
random_search.best_params_
# Out:
# {'bootstrap': False,
#  'criterion': 'entropy',
#  'max_depth': 9,
#  'max_features': 28,
#  'min_samples_leaf': 7,
#  'min_samples_split': 4}

# %%
pred_prob = pd.DataFrame(zip(test_df.ID,random_search.predict_proba(test_df)[:,1]),columns=['id','target'])

# %%
pred_prob.to_csv('~/lab04.csv', sep='\t', index=False)

# %%
pred_prob.to_csv('~/lab04s.csv', sep='\t', index=False)
